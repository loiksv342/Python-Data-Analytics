# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv(r'StudentsPerformance.csv')
df.head()

np.random.seed(42)
dates = pd.date_range(start="2023-01-01", end="2023-05-01", freq='ME')
df['date'] = np.random.choice(dates, size=len(df))
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# #### Wykresy liniowe

# %%
x = np.linspace(0,10,1000)
plt.plot(x, np.sin(x+1))
plt.plot(x, np.sin(x+2))
plt.plot(x, np.sin(x+3322))

# %%
x_values_female = [0, 1, 2]  # Punkty na osi X dla kobiet
x_values_male = [0, 1, 2]    # Punkty na osi X dla mężczyzn

# Wartości na osi Y dla kobiet i mężczyzn
y_values_female = [120, 110, 100]  # Różne wartości, aby linia mogła się przeciąć
y_values_male = [123, 115, 105]    # Różne wartości, aby linia mogła się przeciąć

# Tworzymy wykres liniowy
plt.plot(x_values_female, y_values_female, label='Female', marker='o', linestyle='-')
plt.plot(x_values_male, y_values_male, label='Male', marker='o', linestyle='-')

# Ustawiamy etykiety osi X

# Dodajemy etykiety i tytuł
plt.xlabel('X Axis (Arbitrary Points)')
plt.ylabel('Math Score')
plt.title('Math Score Comparison by Gender')
plt.legend()
plt.grid(True)  # Opcjonalnie: Dodanie siatki dla lepszej wizualizacji
plt.show()
